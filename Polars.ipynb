# %% [markdown]
# <a href="https://colab.research.google.com/github/Kishankumar1328/polars/blob/main/Polars.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install polars

# %%
import polars as pl

# %%
df=pl.read_csv("/content/covid_state_level_latest.csv")

# %%
df
# Out:
# shape: (38, 12)
# ┌──────────┬───────────┬───────────┬────────┬───┬────────────┬────────────┬────────────┬───────────┐
# │ State    ┆ Confirmed ┆ Recovered ┆ Deaths ┆ … ┆ Delta_Conf ┆ Delta_Reco ┆ Delta_Deat ┆ State_Not │
# │ ---      ┆ ---       ┆ ---       ┆ ---    ┆   ┆ irmed      ┆ vered      ┆ hs         ┆ es        │
# │ str      ┆ i64       ┆ i64       ┆ i64    ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---       │
# │          ┆           ┆           ┆        ┆   ┆ i64        ┆ i64        ┆ i64        ┆ str       │
# ╞══════════╪═══════════╪═══════════╪════════╪═══╪════════════╪════════════╪════════════╪═══════════╡
# │ Total    ┆ 2025409   ┆ 1377384   ┆ 41638  ┆ … ┆ 0          ┆ 0          ┆ 0          ┆ null      │
# │ Maharash ┆ 479779    ┆ 316375    ┆ 16792  ┆ … ┆ 0          ┆ 0          ┆ 0          ┆ 307 cases │
# │ tra      ┆           ┆           ┆        ┆   ┆            ┆            ┆            ┆ are       │
# ...

# %%
df.head()
# Out:
# shape: (5, 12)
# ┌──────────┬───────────┬───────────┬────────┬───┬────────────┬────────────┬────────────┬───────────┐
# │ State    ┆ Confirmed ┆ Recovered ┆ Deaths ┆ … ┆ Delta_Conf ┆ Delta_Reco ┆ Delta_Deat ┆ State_Not │
# │ ---      ┆ ---       ┆ ---       ┆ ---    ┆   ┆ irmed      ┆ vered      ┆ hs         ┆ es        │
# │ str      ┆ i64       ┆ i64       ┆ i64    ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---       │
# │          ┆           ┆           ┆        ┆   ┆ i64        ┆ i64        ┆ i64        ┆ str       │
# ╞══════════╪═══════════╪═══════════╪════════╪═══╪════════════╪════════════╪════════════╪═══════════╡
# │ Total    ┆ 2025409   ┆ 1377384   ┆ 41638  ┆ … ┆ 0          ┆ 0          ┆ 0          ┆ null      │
# │ Maharash ┆ 479779    ┆ 316375    ┆ 16792  ┆ … ┆ 0          ┆ 0          ┆ 0          ┆ 307 cases │
# │ tra      ┆           ┆           ┆        ┆   ┆            ┆            ┆            ┆ are       │
# ...

# %%
df.tail()
# Out:
# shape: (5, 12)
# ┌──────────┬───────────┬───────────┬────────┬───┬────────────┬────────────┬────────────┬───────────┐
# │ State    ┆ Confirmed ┆ Recovered ┆ Deaths ┆ … ┆ Delta_Conf ┆ Delta_Reco ┆ Delta_Deat ┆ State_Not │
# │ ---      ┆ ---       ┆ ---       ┆ ---    ┆   ┆ irmed      ┆ vered      ┆ hs         ┆ es        │
# │ str      ┆ i64       ┆ i64       ┆ i64    ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---       │
# │          ┆           ┆           ┆        ┆   ┆ i64        ┆ i64        ┆ i64        ┆ str       │
# ╞══════════╪═══════════╪═══════════╪════════╪═══╪════════════╪════════════╪════════════╪═══════════╡
# │ Sikkim   ┆ 829       ┆ 353       ┆ 1      ┆ … ┆ 0          ┆ 0          ┆ 0          ┆ null      │
# │ Mizoram  ┆ 538       ┆ 288       ┆ 0      ┆ … ┆ 0          ┆ 0          ┆ 0          ┆ "Other"   │
# │          ┆           ┆           ┆        ┆   ┆            ┆            ┆            ┆ case in   │
# ...

# %%
df.sample()
# Out:
# shape: (1, 12)
# ┌──────────┬───────────┬───────────┬────────┬───┬────────────┬────────────┬────────────┬───────────┐
# │ State    ┆ Confirmed ┆ Recovered ┆ Deaths ┆ … ┆ Delta_Conf ┆ Delta_Reco ┆ Delta_Deat ┆ State_Not │
# │ ---      ┆ ---       ┆ ---       ┆ ---    ┆   ┆ irmed      ┆ vered      ┆ hs         ┆ es        │
# │ str      ┆ i64       ┆ i64       ┆ i64    ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---       │
# │          ┆           ┆           ┆        ┆   ┆ i64        ┆ i64        ┆ i64        ┆ str       │
# ╞══════════╪═══════════╪═══════════╪════════╪═══╪════════════╪════════════╪════════════╪═══════════╡
# │ Madhya   ┆ 36564     ┆ 26902     ┆ 946    ┆ … ┆ 0          ┆ 0          ┆ 0          ┆ null      │
# │ Pradesh  ┆           ┆           ┆        ┆   ┆            ┆            ┆            ┆           │
# └──────────┴───────────┴───────────┴────────┴───┴────────────┴────────────┴────────────┴───────────┘

# %%
type(df)
# Out:
# polars.dataframe.frame.DataFrame

# %%
df.select(["State","Confirmed","Recovered","Deaths","Active"])
# Out:
# shape: (38, 5)
# ┌─────────────────────────────┬───────────┬───────────┬────────┬────────┐
# │ State                       ┆ Confirmed ┆ Recovered ┆ Deaths ┆ Active │
# │ ---                         ┆ ---       ┆ ---       ┆ ---    ┆ ---    │
# │ str                         ┆ i64       ┆ i64       ┆ i64    ┆ i64    │
# ╞═════════════════════════════╪═══════════╪═══════════╪════════╪════════╡
# │ Total                       ┆ 2025409   ┆ 1377384   ┆ 41638  ┆ 605933 │
# │ Maharashtra                 ┆ 479779    ┆ 316375    ┆ 16792  ┆ 146305 │
# │ Tamil Nadu                  ┆ 279144    ┆ 221087    ┆ 4571   ┆ 53486  │
# │ Delhi                       ┆ 141531    ┆ 127124    ┆ 4059   ┆ 10348  │
# │ …                           ┆ …         ┆ …         ┆ …      ┆ …      │
# │ Mizoram                     ┆ 538       ┆ 288       ┆ 0      ┆ 249    │
# │ Andaman and Nicobar Islands ┆ 1123      ┆ 355       ┆ 16     ┆ 752    │
# ...

# %%
df.filter(pl.col("Deaths")>5000)
# Out:
# shape: (2, 12)
# ┌──────────┬───────────┬───────────┬────────┬───┬────────────┬────────────┬────────────┬───────────┐
# │ State    ┆ Confirmed ┆ Recovered ┆ Deaths ┆ … ┆ Delta_Conf ┆ Delta_Reco ┆ Delta_Deat ┆ State_Not │
# │ ---      ┆ ---       ┆ ---       ┆ ---    ┆   ┆ irmed      ┆ vered      ┆ hs         ┆ es        │
# │ str      ┆ i64       ┆ i64       ┆ i64    ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---       │
# │          ┆           ┆           ┆        ┆   ┆ i64        ┆ i64        ┆ i64        ┆ str       │
# ╞══════════╪═══════════╪═══════════╪════════╪═══╪════════════╪════════════╪════════════╪═══════════╡
# │ Total    ┆ 2025409   ┆ 1377384   ┆ 41638  ┆ … ┆ 0          ┆ 0          ┆ 0          ┆ null      │
# │ Maharash ┆ 479779    ┆ 316375    ┆ 16792  ┆ … ┆ 0          ┆ 0          ┆ 0          ┆ 307 cases │
# │ tra      ┆           ┆           ┆        ┆   ┆            ┆            ┆            ┆ are       │
# ...

# %%
df.sort(by="State")
# Out:
# shape: (38, 12)
# ┌──────────┬───────────┬───────────┬────────┬───┬────────────┬────────────┬────────────┬───────────┐
# │ State    ┆ Confirmed ┆ Recovered ┆ Deaths ┆ … ┆ Delta_Conf ┆ Delta_Reco ┆ Delta_Deat ┆ State_Not │
# │ ---      ┆ ---       ┆ ---       ┆ ---    ┆   ┆ irmed      ┆ vered      ┆ hs         ┆ es        │
# │ str      ┆ i64       ┆ i64       ┆ i64    ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---       │
# │          ┆           ┆           ┆        ┆   ┆ i64        ┆ i64        ┆ i64        ┆ str       │
# ╞══════════╪═══════════╪═══════════╪════════╪═══╪════════════╪════════════╪════════════╪═══════════╡
# │ Andaman  ┆ 1123      ┆ 355       ┆ 16     ┆ … ┆ 0          ┆ 0          ┆ 0          ┆ null      │
# │ and      ┆           ┆           ┆        ┆   ┆            ┆            ┆            ┆           │
# │ Nicobar  ┆           ┆           ┆        ┆   ┆            ┆            ┆            ┆           │
# ...

# %%
df.max()
# Out:
# shape: (1, 12)
# ┌──────────┬───────────┬───────────┬────────┬───┬────────────┬────────────┬────────────┬───────────┐
# │ State    ┆ Confirmed ┆ Recovered ┆ Deaths ┆ … ┆ Delta_Conf ┆ Delta_Reco ┆ Delta_Deat ┆ State_Not │
# │ ---      ┆ ---       ┆ ---       ┆ ---    ┆   ┆ irmed      ┆ vered      ┆ hs         ┆ es        │
# │ str      ┆ i64       ┆ i64       ┆ i64    ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---       │
# │          ┆           ┆           ┆        ┆   ┆ i64        ┆ i64        ┆ i64        ┆ str       │
# ╞══════════╪═══════════╪═══════════╪════════╪═══╪════════════╪════════════╪════════════╪═══════════╡
# │ West     ┆ 2025409   ┆ 1377384   ┆ 41638  ┆ … ┆ 0          ┆ 0          ┆ 0          ┆ [June     │
# │ Bengal   ┆           ┆           ┆        ┆   ┆            ┆            ┆            ┆ 17]:      │
# │          ┆           ┆           ┆        ┆   ┆            ┆            ┆            ┆ One case  │
# ...

# %%
df.min()
# Out:
# shape: (1, 12)
# ┌──────────┬───────────┬───────────┬────────┬───┬────────────┬────────────┬────────────┬───────────┐
# │ State    ┆ Confirmed ┆ Recovered ┆ Deaths ┆ … ┆ Delta_Conf ┆ Delta_Reco ┆ Delta_Deat ┆ State_Not │
# │ ---      ┆ ---       ┆ ---       ┆ ---    ┆   ┆ irmed      ┆ vered      ┆ hs         ┆ es        │
# │ str      ┆ i64       ┆ i64       ┆ i64    ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---       │
# │          ┆           ┆           ┆        ┆   ┆ i64        ┆ i64        ┆ i64        ┆ str       │
# ╞══════════╪═══════════╪═══════════╪════════╪═══╪════════════╪════════════╪════════════╪═══════════╡
# │ Andaman  ┆ 0         ┆ 0         ┆ 0      ┆ … ┆ 0          ┆ 0          ┆ 0          ┆ "Other"   │
# │ and      ┆           ┆           ┆        ┆   ┆            ┆            ┆            ┆ case in   │
# │ Nicobar  ┆           ┆           ┆        ┆   ┆            ┆            ┆            ┆ MZ is a   │
# ...

# %%
df.drop_nulls()#see for null  the data
# Out:
# shape: (15, 12)
# ┌──────────┬───────────┬───────────┬────────┬───┬────────────┬────────────┬────────────┬───────────┐
# │ State    ┆ Confirmed ┆ Recovered ┆ Deaths ┆ … ┆ Delta_Conf ┆ Delta_Reco ┆ Delta_Deat ┆ State_Not │
# │ ---      ┆ ---       ┆ ---       ┆ ---    ┆   ┆ irmed      ┆ vered      ┆ hs         ┆ es        │
# │ str      ┆ i64       ┆ i64       ┆ i64    ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---       │
# │          ┆           ┆           ┆        ┆   ┆ i64        ┆ i64        ┆ i64        ┆ str       │
# ╞══════════╪═══════════╪═══════════╪════════╪═══╪════════════╪════════════╪════════════╪═══════════╡
# │ Maharash ┆ 479779    ┆ 316375    ┆ 16792  ┆ … ┆ 0          ┆ 0          ┆ 0          ┆ 307 cases │
# │ tra      ┆           ┆           ┆        ┆   ┆            ┆            ┆            ┆ are       │
# │          ┆           ┆           ┆        ┆   ┆            ┆            ┆            ┆ marked as │
# ...

# %%
df.groupby(by="Deaths").agg(pl.col("Active").mean())
# Out:
# shape: (36, 2)
# ┌────────┬─────────┐
# │ Deaths ┆ Active  │
# │ ---    ┆ ---     │
# │ i64    ┆ f64     │
# ╞════════╪═════════╡
# │ 2      ┆ 406.0   │
# │ 589    ┆ 20358.0 │
# │ 2579   ┆ 14708.0 │
# │ 2897   ┆ 75067.0 │
# │ …      ┆ …       │
# │ 6      ┆ 1752.0  │
# │ 126    ┆ 15464.0 │
# │ 31     ┆ 1898.0  │
# │ 7      ┆ 411.0   │
# └────────┴─────────┘

# %%
k=pl.read_csv("/content/covid_state_level_latest.csv")
k
# Out:
# shape: (38, 12)
# ┌──────────┬───────────┬───────────┬────────┬───┬────────────┬────────────┬────────────┬───────────┐
# │ State    ┆ Confirmed ┆ Recovered ┆ Deaths ┆ … ┆ Delta_Conf ┆ Delta_Reco ┆ Delta_Deat ┆ State_Not │
# │ ---      ┆ ---       ┆ ---       ┆ ---    ┆   ┆ irmed      ┆ vered      ┆ hs         ┆ es        │
# │ str      ┆ i64       ┆ i64       ┆ i64    ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---       │
# │          ┆           ┆           ┆        ┆   ┆ i64        ┆ i64        ┆ i64        ┆ str       │
# ╞══════════╪═══════════╪═══════════╪════════╪═══╪════════════╪════════════╪════════════╪═══════════╡
# │ Total    ┆ 2025409   ┆ 1377384   ┆ 41638  ┆ … ┆ 0          ┆ 0          ┆ 0          ┆ null      │
# │ Maharash ┆ 479779    ┆ 316375    ┆ 16792  ┆ … ┆ 0          ┆ 0          ┆ 0          ┆ 307 cases │
# │ tra      ┆           ┆           ┆        ┆   ┆            ┆            ┆            ┆ are       │
# ...

# %%
kk=pl.read_csv("/content/covid_vaccine_statewise - covid_vaccine_statewise (1).csv")
kk
# Out:
# shape: (7_845, 24)
# ┌──────────┬───────┬────────────┬──────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ Updated  ┆ State ┆ Total      ┆ Sessions ┆ … ┆ Male(Indiv ┆ Female(Ind ┆ Transgende ┆ Total Indi │
# │ On       ┆ ---   ┆ Doses Admi ┆ ---      ┆   ┆ iduals Vac ┆ ividuals   ┆ r(Individu ┆ viduals    │
# │ ---      ┆ str   ┆ nistered   ┆ i64      ┆   ┆ cinated)   ┆ Vaccinated ┆ als        ┆ Vaccinated │
# │ str      ┆       ┆ ---        ┆          ┆   ┆ ---        ┆ )          ┆ Vaccinat…  ┆ ---        │
# │          ┆       ┆ i64        ┆          ┆   ┆ i64        ┆ ---        ┆ ---        ┆ i64        │
# │          ┆       ┆            ┆          ┆   ┆            ┆ i64        ┆ i64        ┆            │
# ╞══════════╪═══════╪════════════╪══════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 16/01/20 ┆ India ┆ 48276      ┆ 3455     ┆ … ┆ 23757      ┆ 24517      ┆ 2          ┆ 48276      │
# ...

# %%
joined_df=k.join(kk,on="State")
joined_df
# Out:
# shape: (7_633, 35)
# ┌─────────┬───────────┬───────────┬────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ State   ┆ Confirmed ┆ Recovered ┆ Deaths ┆ … ┆ Male(Indiv ┆ Female(Ind ┆ Transgende ┆ Total Indi │
# │ ---     ┆ ---       ┆ ---       ┆ ---    ┆   ┆ iduals Vac ┆ ividuals   ┆ r(Individu ┆ viduals    │
# │ str     ┆ i64       ┆ i64       ┆ i64    ┆   ┆ cinated)   ┆ Vaccinated ┆ als        ┆ Vaccinated │
# │         ┆           ┆           ┆        ┆   ┆ ---        ┆ )          ┆ Vaccinat…  ┆ ---        │
# │         ┆           ┆           ┆        ┆   ┆ i64        ┆ ---        ┆ ---        ┆ i64        │
# │         ┆           ┆           ┆        ┆   ┆            ┆ i64        ┆ i64        ┆            │
# ╞═════════╪═══════════╪═══════════╪════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ Andaman ┆ 1123      ┆ 355       ┆ 16     ┆ … ┆ null       ┆ null       ┆ null       ┆ 23         │
# ...

# %%
df=joined_df.to_pandas()
df
# Out:
#                             State  Confirmed  Recovered  Deaths  Active  \
# 0     Andaman and Nicobar Islands       1123        355      16     752
# 1     Andaman and Nicobar Islands       1123        355      16     752
# 2     Andaman and Nicobar Islands       1123        355      16     752
# 3     Andaman and Nicobar Islands       1123        355      16     752
# 4     Andaman and Nicobar Islands       1123        355      16     752
# ...                           ...        ...        ...     ...     ...
# 7628                  West Bengal      86754      61023    1902   23829
# 7629                  West Bengal      86754      61023    1902   23829
# 7630                  West Bengal      86754      61023    1902   23829
# 7631                  West Bengal      86754      61023    1902   23829
# 7632                  West Bengal      86754      61023    1902   23829
#
#         Last_Updated_Time  Migrated_Other State_code  Delta_Confirmed  \
# ...
